# %%
import pandas

# %%
props = pandas.read_csv("prop-committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.committee_position.value_counts().reset_index()
# Out:
#      index  committee_position
# 0  SUPPORT                  72
# 1   OPPOSE                  30

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props[props.prop_name == "PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE."]
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 35  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 36  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 37  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 38  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 39  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 40  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 41  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 42  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 43  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 44  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 45  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 46  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
pot = props[props.prop_name == "PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE."]

# %%
pot.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 35  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 36  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 37  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 38  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 39  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#     ccdc_prop_id                                          prop_name  \
# 35            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 36            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 37            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 38            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 39            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 35                417                 1385745
# ...

# %%
pot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 35 to 47
# Data columns (total 8 columns):
# ocd_prop_id               13 non-null object
# calaccess_prop_id         13 non-null int64
# ccdc_prop_id              13 non-null int64
# prop_name                 13 non-null object
# ccdc_committee_id         13 non-null int64
# calaccess_committee_id    13 non-null int64
# committee_name            13 non-null object
# committee_position        13 non-null object
# dtypes: int64(4), object(4)
# memory usage: 936.0+ bytes

# %%
pandas.read_csv("contributions.csv")
# Out:
#        calaccess_committee_id  \
# 0                     1386560
# 1                     1386560
# 2                     1386560
# 3                     1386560
# 4                     1386560
# 5                     1386560
# 6                     1386560
# 7                     1386560
# 8                     1386560
# 9                     1386560
# 10                    1386560
# 11                    1386560
# 12                    1386560
# 13                    1386560
# 14                    1386560
# 15                    1386560
# 16                    1386560
# 17                    1386560
# 18                    1386560
# 19                    1386560
# 20                    1386560
# 21                    1386560
# 22                    1386560
# 23                    1386560
# 24                    1386560
# 25                    1386560
# 26                    1372902
# 27                    1372902
# 28                    1372902
# 29                    1372902
# ...

# %%
contribs = pandas.read_csv("contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.tail()
# Out:
#        calaccess_committee_id  \
# 56756                 1362973
# 56757                 1362973
# 56758                 1362973
# 56759                 1362973
# 56760                 1362973
#
#                                           committee_name  calaccess_filing_id  \
# 56756  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2009922
# 56757  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2009922
# 56758  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2033916
# 56759  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2082752
# 56760  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2082752
#
#       date_received                               contributor_lastname  \
# 56756    2015-12-22             CALIFORNIA HEALTH FOUNDATION AND TRUST
# 56757    2015-12-22        CFHS HOLDINGS, INC./MARINA DEL REY HOSPITAL
# 56758    2016-01-20                                     DIGNITY HEALTH
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56761 entries, 0 to 56760
# Data columns (total 13 columns):
# calaccess_committee_id          56761 non-null int64
# committee_name                  56761 non-null object
# calaccess_filing_id             56761 non-null int64
# date_received                   56761 non-null object
# contributor_lastname            56757 non-null object
# contributor_firstname           53794 non-null object
# contributor_city                56751 non-null object
# contributor_state               56745 non-null object
# contributor_zip                 56748 non-null object
# contributor_employer            48962 non-null object
# contributor_occupation          53656 non-null object
# contributor_is_self_employed    56761 non-null bool
# amount                          56761 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.3+ MB

# %%
pot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 35 to 47
# Data columns (total 8 columns):
# ocd_prop_id               13 non-null object
# calaccess_prop_id         13 non-null int64
# ccdc_prop_id              13 non-null int64
# prop_name                 13 non-null object
# ccdc_committee_id         13 non-null int64
# calaccess_committee_id    13 non-null int64
# committee_name            13 non-null object
# committee_position        13 non-null object
# dtypes: int64(4), object(4)
# memory usage: 936.0+ bytes

# %%
pandas.merge(pot, contribs, on="calaccess_committee_id")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 1    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 2    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 3    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 4    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 5    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 6    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 7    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 8    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 9    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 10   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 11   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
merged = pandas.merge(pot, contribs, on="calaccess_committee_id")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237 entries, 0 to 236
# Data columns (total 20 columns):
# ocd_prop_id                     237 non-null object
# calaccess_prop_id               237 non-null int64
# ccdc_prop_id                    237 non-null int64
# prop_name                       237 non-null object
# ccdc_committee_id               237 non-null int64
# calaccess_committee_id          237 non-null int64
# committee_name_x                237 non-null object
# committee_position              237 non-null object
# committee_name_y                237 non-null object
# calaccess_filing_id             237 non-null int64
# date_received                   237 non-null object
# contributor_lastname            237 non-null object
# contributor_firstname           117 non-null object
# contributor_city                237 non-null object
# contributor_state               237 non-null object
# contributor_zip                 237 non-null object
# ...

# %%
merged.sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 3    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 211  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 17   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 4    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 16   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#      ccdc_prop_id                                          prop_name  \
# 3              76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 211            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 17             76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 4              76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 16             76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 3                  417                 1385745
# ...

# %%
merged.amount
# Out:
# 0       550000.00
# 1       420000.00
# 2      1000000.00
# 3      1970000.00
# 4      1403000.00
# 5       500000.00
# 6       200000.00
# 7        97000.00
# 8      1000000.00
# 9       500000.00
# 10     1000000.00
# 11      100000.00
# 12       50000.00
# 13      100000.00
# 14       35000.00
# 15       35000.00
# 16     1200000.00
# 17     1438764.06
# 18      100000.00
# 19      100000.00
# 20         100.00
# 21         166.00
# 22      250000.00
# 23      150000.00
# 24      200000.00
# 25       15000.00
# 26         100.00
# 27       12500.00
# 28      100000.00
# 29         100.00
#           ...
# 207        100.00
# 208        500.00
# 209        250.00
# 210     250000.00
# 211    1500000.00
# 212     100000.00
# 213       5000.00
# 214     250000.00
# 215       5000.00
# 216     600000.00
# 217      20000.00
# 218      14567.50
# 219      14722.00
# 220      15090.50
# 221      14567.50
# 222      14722.00
# 223      15090.50
# 224     100000.00
# 225      29304.00
# ...

# %%
merged.amount.sum()
# Out:
# 20097369.73

# %%
merged.sort_values(['contributor_lastname','amount'])
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 20   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 95   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 185  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 164  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 204  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 194  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 70   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 209  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 108  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 135  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 182  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 82   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
support
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 1    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 2    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 3    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 4    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 5    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 6    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 7    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 8    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 9    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 10   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 11   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
oppose
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 64   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 65   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 66   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 67   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 68   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 69   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 70   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 71   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 72   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 73   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 74   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 75   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
len(support)
# Out:
# 91

# %%
len(oppose)
# Out:
# 146

# %%
oppose.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 181  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 204  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 175  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 164  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 70   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 199  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 194  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 179  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 188  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 155  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 195  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 68   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
oppose.sort_values("amount", ascending=False).head(10)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 181  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 204  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 175  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 164  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 70   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 199  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 194  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 179  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 188  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 155  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#      ccdc_prop_id                                          prop_name  \
# 181            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# ...

# %%
support.amount.sum()
# Out:
# 19307322.729999997

# %%
support.amount.sum()/merged.amount.sum()
# Out:
# 0.96068903490287716

# %%
oppose.amount.sum()/merged.amount.sum()
# Out:
# 0.039310965097122688

# %%
support.amount.median()
# Out:
# 29820.0

# %%
support.amount.mode()
# Out:
# 0    100000.0
# dtype: float64

# %%
support.groupby(["contributor_lastname", "contributor_firstname"]).amount.sum()
# Out:
# contributor_lastname  contributor_firstname
# AGUILAR               JEREMIAH                     100.0
# CIFELLI               DEBBIE                       100.0
# DELANEY               M QUINN                    75000.0
#                       M. QUINN                  100000.0
# DOWNEY                SUSAN                      35000.0
# DOWNEY, JR.           ROBERT                     35000.0
# GUIDA                 VINCENT                      100.0
# GUNTHER               ADAM                       10000.0
# HEISING               CAITLIN                    50000.0
# IRWIN                 ANNE                       20000.0
# MALLICK-WILLIAMS      ALEXANDRA                  15000.0
# MOSKOVITZ             DUSTIN                    600000.0
# O'KEEFE               MAIREAD                      200.0
# PRITZKER              NICHOLAS                  100000.0
# QUINONES              CARMEN                       100.0
# SEEMAN                PAUL                         100.0
# ...

# %%
support.groupby(["contributor_lastname", "contributor_firstname"]).amount.sum().reset_index()
# Out:
#    contributor_lastname contributor_firstname     amount
# 0               AGUILAR              JEREMIAH      100.0
# 1               CIFELLI                DEBBIE      100.0
# 2               DELANEY               M QUINN    75000.0
# 3               DELANEY              M. QUINN   100000.0
# 4                DOWNEY                 SUSAN    35000.0
# 5           DOWNEY, JR.                ROBERT    35000.0
# 6                 GUIDA               VINCENT      100.0
# 7               GUNTHER                  ADAM    10000.0
# 8               HEISING               CAITLIN    50000.0
# 9                 IRWIN                  ANNE    20000.0
# 10     MALLICK-WILLIAMS             ALEXANDRA    15000.0
# 11            MOSKOVITZ                DUSTIN   600000.0
# 12              O'KEEFE               MAIREAD      200.0
# 13             PRITZKER              NICHOLAS   100000.0
# 14             QUINONES                CARMEN      100.0
# ...

# %%
support.groupby(["contributor_lastname", "contributor_firstname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#    contributor_lastname contributor_firstname     amount
# 19               STEYER                THOMAS  1750000.0
# 22           ZUCKERBERG                  MARK  1000000.0
# 11            MOSKOVITZ                DUSTIN   600000.0
# 3               DELANEY              M. QUINN   100000.0
# 13             PRITZKER              NICHOLAS   100000.0
# 16             SHANAHAN             NICOLE A.    85000.0
# 2               DELANEY               M QUINN    75000.0
# 8               HEISING               CAITLIN    50000.0
# 17               SIMONS             ELIZABETH    50000.0
# 5           DOWNEY, JR.                ROBERT    35000.0
# 4                DOWNEY                 SUSAN    35000.0
# 20      TRIGGER KRIEGER               KAITLYN    25000.0
# 9                 IRWIN                  ANNE    20000.0
# 10     MALLICK-WILLIAMS             ALEXANDRA    15000.0
# 7               GUNTHER                  ADAM    10000.0
# ...

# %%
merged.groupby(["contributor_lastname", "contributor_firstname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_lastname contributor_firstname committee_position     amount
# 96                STEYER                THOMAS            SUPPORT  1750000.0
# 114           ZUCKERBERG                  MARK            SUPPORT  1000000.0
# 71             MOSKOVITZ                DUSTIN            SUPPORT   600000.0
# 25               DELANEY              M. QUINN            SUPPORT   100000.0
# 82              PRITZKER              NICHOLAS            SUPPORT   100000.0
# 89              SHANAHAN             NICOLE A.            SUPPORT    85000.0
# 24               DELANEY               M QUINN            SUPPORT    75000.0
# 91                SIMONS             ELIZABETH            SUPPORT    50000.0
# 45               HEISING               CAITLIN            SUPPORT    50000.0
# 29           DOWNEY, JR.                ROBERT            SUPPORT    35000.0
# 28                DOWNEY                 SUSAN            SUPPORT    35000.0
# ...

# %%
support.groupby(["contributor_employer"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#        contributor_employer     amount
# 8          FARALLON CAPITAL  1750000.0
# 7                  FACEBOOK  1000000.0
# 3                     ASANA   600000.0
# 1        AKONADI FOUNDATION   175000.0
# 13     TAO CAPITAL PARTNERS   100000.0
# 5             CLEARACCESSIP    85000.0
# 2        ARTICLE 3 ADVISORS    50000.0
# 11          MAHTOMEDI, INC.    35000.0
# 12          SUKI DUKI, INC.    35000.0
# 9   KAITLYN TRIGGER KRIEGER    25000.0
# 0              ADAM GUNTHER    10000.0
# 10           LINDSAY WESTON     1500.0
# 6     COUNTY OF SANTA CLARA      200.0
# 4          CITY OF CAMPBELL      100.0
# 14       UNITED STATES NAVY      100.0

# %%
oppose.groupby(["contributor_employer"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                              contributor_employer   amount
# 37                            SUDBERRY PROPERTIES  10000.0
# 2                       BERNZOTT CAPITAL ADVISORS  10000.0
# 19                      HOROWITZ MANAGEMENT, INC.  10000.0
# 18                            GALPIN MOTORS, INC.  10000.0
# 38                             SUNCOAST FINANCIAL  10000.0
# 34                          SHOW CIRCUIT MAGAZINE   5000.0
# 12                           CRIVELLO CORPORATION   5000.0
# 23                                 JENNER & BLOCK   1500.0
# 11                            COUNTY OF SAN MATEO   1000.0
# 3                       BUNNIN CHEVROLET CADILLAC   1000.0
# 47                          VOSE PROPERTIES, INC.   1000.0
# 21        JAMES R. MURPHY, JR., A LAW CORPORATION   1000.0
# 13             DUCKETT-WILSON DEVELOPMENT COMPANY   1000.0
# 4                         CASS CONSTRUCTION, INC.    750.0
# 20                INSITUTE OF READING DEVELOPMENT    500.0
# ...

# %%
merged.groupby(["contributor_employer", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(20)
# Out:
#          contributor_employer committee_position     amount
# 23           FARALLON CAPITAL            SUPPORT  1750000.0
# 22                   FACEBOOK            SUPPORT  1000000.0
# 5                       ASANA            SUPPORT   600000.0
# 2          AKONADI FOUNDATION            SUPPORT   175000.0
# 52       TAO CAPITAL PARTNERS            SUPPORT   100000.0
# 13              CLEARACCESSIP            SUPPORT    85000.0
# 4          ARTICLE 3 ADVISORS            SUPPORT    50000.0
# 50            SUKI DUKI, INC.            SUPPORT    35000.0
# 38            MAHTOMEDI, INC.            SUPPORT    35000.0
# 33    KAITLYN TRIGGER KRIEGER            SUPPORT    25000.0
# 27        GALPIN MOTORS, INC.             OPPOSE    10000.0
# 28  HOROWITZ MANAGEMENT, INC.             OPPOSE    10000.0
# 0                ADAM GUNTHER            SUPPORT    10000.0
# 51         SUNCOAST FINANCIAL             OPPOSE    10000.0
# 6   BERNZOTT CAPITAL ADVISORS             OPPOSE    10000.0
# ...

# %%
merged.groupby(["contributor_employer", "committee_position"]).amount.sum().reset_index().sort_values("contributor_employer")
# Out:
#                              contributor_employer     amount
# 0                                    ADAM GUNTHER    10000.0
# 1                           AEROSPACE CORPORATION      500.0
# 2                              AKONADI FOUNDATION   175000.0
# 3                ALAMEDA COUNTY DISTRICT ATTORNEY      100.0
# 4                              ARTICLE 3 ADVISORS    50000.0
# 5                                           ASANA   600000.0
# 6                       BERNZOTT CAPITAL ADVISORS    10000.0
# 7                       BUNNIN CHEVROLET CADILLAC     1000.0
# 8                         CASS CONSTRUCTION, INC.      750.0
# 9                  CHARLES ECKERT III LAW OFFICES      250.0
# 10                              CHRISTOPHER RANCH      500.0
# 11                               CITY OF CAMPBELL      100.0
# 12                      CLAREMONT MCKENNA COLLEGE      200.0
# 13                                  CLEARACCESSIP    85000.0
# ...
